# %%
# !pip install SpeechRecognition
# !pip install PyAudio
# !pip install gTTS
# !apt-get install -y portaudio19-dev
# !pip install pyaudio
# !pip install playsound
# pip install -q -U google-genai

# %%
import os
import time
import playsound
import speech_recognition as sr
from gtts import gTTS
from IPython.display import Audio, display
from google import genai
from google.genai import types

# %%
def speak(text):
  tts = gTTS(text=text, lang ='hi')
  filename = "audio.mp3"
  tts.save(filename)
  display(Audio(filename, autoplay= True))
  os.remove(filename)


speak("hello abhishek and welcome back ")
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def get_audio():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        audio = r.listen(source)
        said = ""
        try:
            said  = r.recognize_google(audio)
            print(said)
        except Exception as e:
            print("Exception: " + str(e))
    return said

# %%
def talk_fun(text, lan):
    client = genai.Client(api_key="AIzaSyBB9HaF06nicdG7-wANFalK-sIIssMj_eo")
    response = client.models.generate_content(
        model="gemini-2.0-flash",
        config=types.GenerateContentConfig(
        system_instruction=f"Respond as if in a chat between User and Gemini. Use only Hindi language and format the replies like this:\n User: ...\n Gemini: ...\n Output only the replies."),
        contents=text
    )
    speak(response.text)
    print(response.text)
text = get_audio()
talk_fun(text, "hindi")
# Out:
# tell me some good jokes
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# User: tell me some good jokes
# Gemini: ज़रूर! यहाँ कुछ मज़ेदार चुटकुले हैं:
#
# 1.  टीचर: बच्चों, बताओ 'सत्यवादी' किसे कहते हैं?
#     बच्चा: जो हमेशा सच बोलता है।
#     टीचर: बहुत अच्छे! अब बताओ, अगर तुम्हारे सामने दो प्लेट लड्डू रखे हों, एक तुम्हारे दादाजी के लिए और एक तुम्हारे लिए, तो तुम कौन सा लड्डू उठाओगे?
#     बच्चा: दादाजी वाला।
#     टीचर: शाबाश! तुम एक सत्यवादी बच्चे हो। क्यों?
#     बच्चा: क्योंकि मुझे पता है कि मैं अपना वाला उठाऊंगा तो दादाजी मुझे मारेंगे!
#
# 2.  एक कंजूस आदमी एक होटल में खाना खाने गया।
#     वेटर: सर, क्या लाऊं?
#     कंजूस: ऐसा करो, दो रोटी ले आओ।
#     वेटर: ठीक है।
#     कंजूस: और एक रोटी वापस ले जाओ!
#
# ...
